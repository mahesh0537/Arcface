# %%
import tensorflow as tf
import backbone as nn
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
model = nn.ResNet(34)

# %%
X = np.load('x_train.npy')
Y = np.load('y_train.npy', allow_pickle=True)

# %%
X.shape
# Out:
# (1476, 112, 112, 3)

# %%
Y.shape
# Out:
# (1476, 1)

# %%
index = []
r = 138
for i in range(1476):
    if r == Y[i]:
        index.append(i)
num = len(index)
k = 1
column = 5
if num%5 == 0:
    row = num/5
else:
    row = (num/5) + 1
fig = plt.figure(figsize=(50, 10*row))
for j in index:
    img = X[j]
    fig.add_subplot(row, column, k)
    k+=1
    plt.imshow(img)
    plt.axis('off')
# Out:
# /home/student/students/Mahesh_Bala/ML_cv/tf24/lib/python3.6/site-packages/ipykernel_launcher.py:16: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   app.launch_new_instance()

# %%
# %timeit y_out = model.predict(X)
# Out:
# 53.2 s ± 38.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
y_out.shape
# Out:
# (1476, 512)

# %%
indices = Y[1]
depth = 1476

# %%
y_train = tf.one_hot(
    indices, depth, on_value=None, off_value=None, axis=None, dtype=None, name=None
)

# %%
y_train.shape
# Out:
# TensorShape([1, 1476])

# %%
indices.shape
# Out:
# (1,)

# %%
Y = np.reshape(Y, (1476))

# %%
y_train
# Out:
# <tf.Tensor: shape=(1, 1476), dtype=float32, numpy=array([[0., 0., 0., ..., 0., 0., 0.]], dtype=float32)>
